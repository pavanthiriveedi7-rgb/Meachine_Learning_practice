# %%
'''
1.Importing modules
2. Importing Data
3. Data analysis(cleaning,modifying)
4. Data split(train,test)
5. Trainig the model
6. Evaluate model
'''

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("/content/train.csv")

# %%
data.head()
# Out:
#    Student_ID  Age  Gender  ... Certifications Backlogs  Placement_Status
# 0        1048   22  Female  ...              1        3        Not Placed
# 1       37820   20  Female  ...              2        1        Not Placed
# 2       49668   22    Male  ...              2        2        Not Placed
# 3       19467   22    Male  ...              2        0            Placed
# 4       23094   20  Female  ...              2        0            Placed
#
# [5 rows x 15 columns]

# %%
data.tail()
# Out:
#        Student_ID  Age  Gender  ... Certifications Backlogs  Placement_Status
# 44995        9362   20    Male  ...              3        1            Placed
# 44996        8940   19  Female  ...              2        0            Placed
# 44997       13097   20  Female  ...              2        0        Not Placed
# 44998       12958   24  Female  ...              2        1        Not Placed
# 44999        9565   23  Female  ...              2        3        Not Placed
#
# [5 rows x 15 columns]

# %%
data.describe()
# Out:
#          Student_ID           Age  ...  Certifications      Backlogs
# count  45000.000000  45000.000000  ...    45000.000000  45000.000000
# mean   24977.962600     20.999333  ...        1.800956      0.888133
# std    14425.605704      1.995071  ...        0.650104      0.970954
# min        1.000000     18.000000  ...        0.000000      0.000000
# 25%    12509.750000     19.000000  ...        1.000000      0.000000
# 50%    24957.500000     21.000000  ...        2.000000      1.000000
# 75%    37475.250000     23.000000  ...        2.000000      2.000000
# max    50000.000000     24.000000  ...        3.000000      3.000000
#
# [8 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            45000 non-null  int64
#  1   Age                   45000 non-null  int64
#  2   Gender                45000 non-null  object
#  3   Degree                45000 non-null  object
#  4   Branch                45000 non-null  object
#  5   CGPA                  45000 non-null  float64
#  6   Internships           45000 non-null  int64
#  7   Projects              45000 non-null  int64
#  8   Coding_Skills         45000 non-null  int64
#  9   Communication_Skills  45000 non-null  int64
#  10  Aptitude_Test_Score   45000 non-null  int64
#  11  Soft_Skills_Rating    45000 non-null  int64
#  12  Certifications        45000 non-null  int64
#  13  Backlogs              45000 non-null  int64
#  14  Placement_Status      45000 non-null  object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 5.1+ MB

# %%
data.isnull()
# Out:
#        Student_ID    Age  Gender  ...  Certifications  Backlogs  Placement_Status
# 0           False  False   False  ...           False     False             False
# 1           False  False   False  ...           False     False             False
# 2           False  False   False  ...           False     False             False
# 3           False  False   False  ...           False     False             False
# 4           False  False   False  ...           False     False             False
# ...           ...    ...     ...  ...             ...       ...               ...
# 44995       False  False   False  ...           False     False             False
# 44996       False  False   False  ...           False     False             False
# 44997       False  False   False  ...           False     False             False
# 44998       False  False   False  ...           False     False             False
# 44999       False  False   False  ...           False     False             False
#
# [45000 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# Student_ID              0
# Age                     0
# Gender                  0
# Degree                  0
# Branch                  0
# CGPA                    0
# Internships             0
# Projects                0
# Coding_Skills           0
# Communication_Skills    0
# Aptitude_Test_Score     0
# Soft_Skills_Rating      0
# Certifications          0
# Backlogs                0
# Placement_Status        0
# dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
# scatter plotting
plt.figure(figsize = (5,5))
plt.scatter(data['Aptitude_Test_Score'],data['CGPA'])
plt.xlabel('Aptitude_Test_Score')
plt.ylabel('CGPA')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.head()
# Out:
#    Student_ID  Age  Gender  ... Certifications Backlogs  Placement_Status
# 0        1048   22  Female  ...              1        3        Not Placed
# 1       37820   20  Female  ...              2        1        Not Placed
# 2       49668   22    Male  ...              2        2        Not Placed
# 3       19467   22    Male  ...              2        0            Placed
# 4       23094   20  Female  ...              2        0            Placed
#
# [5 rows x 15 columns]

# %%
x = data[['CGPA']]     # x----independent values y = m(x1+x2+x3)+c
y = data['Aptitude_Test_Score']  # y----dependent values

# %%
x
# Out:
#        CGPA
# 0      6.29
# 1      6.05
# 2      7.22
# 3      7.78
# 4      7.63
# ...     ...
# 44995  7.84
# 44996  8.28
# 44997  8.88
# 44998  5.90
# 44999  6.28
#
# [45000 rows x 1 columns]

# %%
y
# Out:
# 0        51
# 1        59
# 2        58
# 3        90
# 4        79
#          ..
# 44995    68
# 44996    74
# 44997    83
# 44998    60
# 44999    64
# Name: Aptitude_Test_Score, Length: 45000, dtype: int64

# %%
plt.figure(figsize = (5,5))
plt.plot(data['Aptitude_Test_Score'],data['CGPA'])
plt.xlabel('Aptitude_Test_Score')
plt.ylabel('CGPA')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(5,5))
plt.bar(data['Aptitude_Test_Score'],data['CGPA'])
plt.xlabel('Aptitude_Test_Score')
plt.ylabel('CGPA')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train
# Out:
#        CGPA
# 42851  7.20
# 19484  5.89
# 5580   8.16
# 39981  5.45
# 13350  6.89
# ...     ...
# 40059  5.37
# 28017  6.91
# 29199  6.37
# 40061  6.08
# 17673  6.80
#
# [36000 rows x 1 columns]

# %%
y_train
# Out:
# 42851    91
# 19484    47
# 5580     73
# 39981    61
# 13350    70
#          ..
# 40059    61
# 28017    68
# 29199    54
# 40061    39
# 17673    69
# Name: Aptitude_Test_Score, Length: 36000, dtype: int64

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (36000, 1)
# (9000, 1)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (36000,)
# (9000,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
x_test.head()
# Out:
#        CGPA
# 5216   6.87
# 5502   6.33
# 3375   6.16
# 27464  7.54
# 25138  8.11
#        CGPA
# 5216   6.87
# 5502   6.33
# 3375   6.16
# 27464  7.54
# 25138  8.11

# %%
lr.predict(x_test)
# Out:
# array([68.10939585, 62.7538084 , 61.06779012, ..., 67.41515304,
#        60.5719024 , 68.40692849])

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test.iloc[10]
# Out:
# CGPA    5.82
# Name: 617, dtype: float64

# %%
y_test.iloc[10]
# Out:
# np.int64(55)

# %%
lr.predict([[10]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([99.1519676])

# %%
lr.predict([[6.68]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([66.22502249])

# %%
lr.predict([[9.0]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([89.23421305])

# %%
# ploting Regression Line
figure = plt.figsize = (5,5)
plt.scatter(data['Aptitude_Test_Score'],data['CGPA'])
plt.plot(x_test,lr.predict(x_test),color = 'red')
plt.ylabel('Aptitude_Test_Score')
plt.xlabel('CGPA')
plt.show()

# %%
lr.coef_
# Out:
# array([9.91775455])

# %%
lr.score(x_test,y_test)
# Out:
# 0.4945705059384933
